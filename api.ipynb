# %%
import pandas as pd
import numpy as np
from fastparquet import ParquetFile
import openpyxl 
import pyodbc

# %% [markdown]
# ## CONVERSION DE X TIPO A CSV !

# %%
# Carga de archivos TXT


data_txt = pd.read_csv("precios_semana_20200518.txt")
  
# Guardado De archivos Conversion De TXT A CSV
data_txt.to_csv('precios_semana_20200518.csv',  
                  index = None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [17], line 4
#       1 # Carga de archivos TXT
# ----> 4 data_txt = pd.read_csv("precios_semana_20200518.txt")
#       6 # Guardado De archivos Conversion De TXT A CSV
#       7 data_txt.to_csv('precios_semana_20200518.csv',
#       8                   index = None)
#
# NameError: name 'pd' is not defined

# %%
# Carga de archivos JSON
data_json = pd.read_json("precios_semana_20200503.json")
  
# Guardado De archivos Conversion De JSON A CSV
data_json.to_csv('precios_semana_20200503.csv',  
                  index = None)

# %%
# Carga de archivos XLSX
data_xlsx = pd.read_excel('precios_semanas_20200419_20200426.xlsx')

# Guardado De archivos Conversion De XLSX A CSV
data_xlsx.to_csv('precios_semanas_20200419_20200426.csv')

# %%
# Carga de archivos mediante MEDIANTE FASTPARQUET 
pf = ParquetFile("producto.parquet")

# Conversion de dataframe Por Pandas
dataFrame = pf.to_pandas()

# Extracion de PARQUET A CSV
dataFrame.to_csv("producto.csv", index = False)

# %% [markdown]
# ## ARCHIVOS SIN DATOS !!

# %% [markdown]
# ## DATO1

# %%
## Carga de precio creado

data_1 = pd.read_csv("8_precios_semana_20200413.csv")
data_1.head()
# Out:
#    precio producto_id sucursal_id
# 0   29.90        1663     2-1-014
# 1   29.90        2288     2-1-032
# 2   39.90        2288     2-1-096
# 3  499.99      205870     9-1-686
# 4  519.99      205870     9-2-248

# %%
## MUESTRE LOS DATOS UNICO PRODUCTO

data_1['producto_id'].unique().tolist()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 data_1['producto_id'].unique().tolist()
#
# NameError: name 'data_1' is not defined

# %%
data_1
# Out:
#         precio    producto_id sucursal_id
# 0        29.90           1663     2-1-014
# 1        29.90           2288     2-1-032
# 2        39.90           2288     2-1-096
# 3       499.99         205870     9-1-686
# 4       519.99         205870     9-2-248
# ...        ...            ...         ...
# 472161  139.99  9569753142128      25-1-1
# 472162   34.99  9795403001143      25-1-1
# 472163  312.50  9990385651922       5-1-3
# 472164  312.50  9990385651939       5-1-3
# 472165  198.90  9990385651946       5-1-3
#
# [472166 rows x 3 columns]

# %%
## Total De columnas Y filas !
data_1.count().sort_values()
# Out:
# precio         472166
# producto_id    472166
# sucursal_id    472166
# dtype: int64

# %%
data_1.dtypes
# Out:
# precio         float64
# producto_id     object
# sucursal_id     object
# dtype: object

# %%
#Saber datos null
data_1.isnull().sum()
# Out:
# precio         13
# producto_id    15
# sucursal_id    15
# dtype: int64

# %%
## ERROR Q ME PERMITE VER LOS DATO DE PRODUCTO CON DOBLE --


data_1['producto_id'] = data_1['producto_id'].astype(str).astype(int)
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In [169], line 1
# ----> 1 data_1['producto_id'] = data_1['producto_id'].astype(str).astype(int)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\generic.py:6245, in NDFrame.astype(self, dtype, copy, errors)
#    6238     results = [
#    6239         self.iloc[:, i].astype(dtype, copy=copy)
#    6240         for i in range(len(self.columns))
#    6241     ]
#    6243 else:
#    6244     # else, only a single dtype is given
# -> 6245     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6246     return self._constructor(new_data).__finalize__(self, method="astype")
#    6248 # GH 33113: handle empty frame or series
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\internals\managers.py:446, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
## TRANFORMAR DATOS SIN 0 a +13 Zero

data_1["producto_id"]= data_1["producto_id"].astype(str)

# CANTIDAD DE 0
width = 13
  
# PRODUCTO MODIFICA LA CANTIDAD DE 0
data_1["producto_id"]= data_1["producto_id"].str.zfill(width)
  
# SALIDA
data_1
# Out:
#         precio    producto_id sucursal_id
# 0        29.90  0000000001663     2-1-014
# 1        29.90  0000000002288     2-1-032
# 2        39.90  0000000002288     2-1-096
# 3       499.99  0000000205870     9-1-686
# 4       519.99  0000000205870     9-2-248
# ...        ...            ...         ...
# 472161  139.99  9569753142128      25-1-1
# 472162   34.99  9795403001143      25-1-1
# 472163  312.50  9990385651922       5-1-3
# 472164  312.50  9990385651939       5-1-3
# 472165  198.90  9990385651946       5-1-3
#
# [472166 rows x 3 columns]

# %%
## COMPLETO DATO FALTANTE

data_1.fillna({'producto_id': '0'}, inplace=True)
data_1.fillna({'precio': '0'}, inplace=True)
data_1.fillna({'sucursal_id': '0'}, inplace=True)

# %%
## TIPO DE DATO POR COLUMNA

data_1.dtypes
# Out:
# precio         object
# producto_id    object
# sucursal_id    object
# dtype: object

# %%
## CAMBIAR TYPO DE DATO PRECIO OBJECT A FLOAT64
data_1['precio']=data_1['precio'].astype('float64')

# %%
## ERROR Q ME PERMITE VER LOS DATO DE PRODUCTO CON DOBLE --

data_1['producto_id'] = data_1['producto_id'].astype(str).astype(int64)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [138], line 1
# ----> 1 data_1['producto_id'] = data_1['producto_id'].astype(str).astype(int64)
#
# NameError: name 'int64' is not defined

# %%
## LIMPIEZA DE DATOS CON EL DOBLE --

data_1['producto_id'] = data_1['producto_id'].str.split('3-1-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('3-2-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('3-3-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('4-1-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('4-2-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('4-4-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('4-5-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('5-1-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('5-2-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('5-4-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('5-5-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('6-1-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('6-2-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('6-4-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('6-5-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('7-1-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('7-2-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('7-4-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('7-5-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('8-1-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('8-2-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('8-4-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('8-5-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('9-1-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('9-2-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('9-3-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('9-4-').str[-1]


data_1['producto_id'] = data_1['producto_id'].str.split('10-1-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('10-2-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('10-3-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('11-1-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('11-2-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('11-4-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('11-5-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('12-1-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('12-2-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('12-3-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('13-1-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('13-2-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('13-3-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('14-1-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('14-2-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('14-3-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('15-1-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('15-2-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('15-4-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('15-5-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('16-1-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('16-2-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('16-3-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('17-1-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('17-2-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('17-3-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('20-1-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('20-2-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('20-3-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('21-1-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('21-2-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('21-3-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('22-1-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('25-1-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('25-2-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('25-3-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('36-3-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('36-4-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('36-5-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('36-6-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('45-1-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('45-2-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('45-3-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('46-1-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('46-2-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('46-3-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('47-1-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('47-2-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('47-3-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('48-1-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('48-2-').str[-1]
data_1['producto_id'] = data_1['producto_id'].str.split('48-3-').str[-1]

# %%
## ERROR Q ME PERMITE VER LOS DATO DE PRODUCTO CON DOBLE --

data_1['producto_id']=data_1['producto_id'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In [171], line 1
# ----> 1 data_1['producto_id']=data_1['producto_id'].astype('int')
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\generic.py:6245, in NDFrame.astype(self, dtype, copy, errors)
#    6238     results = [
#    6239         self.iloc[:, i].astype(dtype, copy=copy)
#    6240         for i in range(len(self.columns))
#    6241     ]
#    6243 else:
#    6244     # else, only a single dtype is given
# -> 6245     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6246     return self._constructor(new_data).__finalize__(self, method="astype")
#    6248 # GH 33113: handle empty frame or series
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\internals\managers.py:446, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
## TRANFORMACIO DE DATAFRAME A LISTA

precios_semana_20200413 = data_1.values.tolist()

# %%
## VISTA PARA LA CARGA MEDIANTE pyodbc A SQL!

precios_semana_20200413
# Out:
# [[29.9, '0000000001663', '2-1-014'],
#  [29.9, '0000000002288', '2-1-032'],
#  [39.9, '0000000002288', '2-1-096'],
#  [499.99, '0000000205870', '9-1-686'],
#  [519.99, '0000000205870', '9-2-248'],
#  [539.99, '0000000205870', '9-2-42'],
#  [539.99, '0000000205870', '9-3-628'],
#  [589.99, '0000000205894', '9-1-686'],
#  [189.99, '0000000205955', '9-1-686'],
#  [104.99, '0000000205979', '9-1-686'],
#  [259.99, '0000000206020', '9-1-686'],
#  [279.99, '0000000206044', '9-1-686'],
#  [229.99, '0000000206051', '9-1-686'],
#  [459.99, '0000000206105', '9-1-686'],
#  [389.99, '0000000206136', '9-1-686'],
#  [299.99, '0000000206143', '9-1-686'],
#  [339.99, '0000000206181', '9-1-686'],
#  [339.99, '0000000206198', '9-1-686'],
#  [369.99, '0000000206235', '9-1-686'],
#  [399.99, '0000000206280', '9-1-686'],
#  [414.99, '0000000206297', '9-1-686'],
#  [399.99, '0000000206303', '9-1-686'],
#  [399.99, '0000000206310', '9-1-686'],
#  [559.99, '0000000206334', '9-1-686'],
# ...

# %%
data_1.to_csv('precios_semana_20200413_ok4.csv',  
                  index = None)

# %%
data_1
# Out:
#         precio    producto_id sucursal_id
# 0        29.90  0000000001663     2-1-014
# 1        29.90  0000000002288     2-1-032
# 2        39.90  0000000002288     2-1-096
# 3       499.99  0000000205870     9-1-686
# 4       519.99  0000000205870     9-2-248
# ...        ...            ...         ...
# 472161  139.99  9569753142128      25-1-1
# 472162   34.99  9795403001143      25-1-1
# 472163  312.50  9990385651922       5-1-3
# 472164  312.50  9990385651939       5-1-3
# 472165  198.90  9990385651946       5-1-3
#
# [472166 rows x 3 columns]

# %% [markdown]
# ## DATO2

# %%
## Carga de precio creado

data_2 = pd.read_csv("precios_semana_20200503.csv")
data_2.head()
# Out:
#    precio    producto_id sucursal_id
# 0   29.90  0000000002288     2-1-187
# 1   39.90  0000000002288     2-3-247
# 2  499.99  0000000205870     9-1-685
# 3  539.99  0000000205870      9-2-22
# 4  519.99  0000000205870      9-2-59

# %%
data_2
# Out:
#         precio    producto_id sucursal_id
# 0        29.90  0000000002288     2-1-187
# 1        39.90  0000000002288     2-3-247
# 2       499.99  0000000205870     9-1-685
# 3       539.99  0000000205870      9-2-22
# 4       519.99  0000000205870      9-2-59
# ...        ...            ...         ...
# 397729  139.99  9569753142128      25-1-1
# 397730   34.99  9795403001143      25-1-1
# 397731  312.50  9990385651922       5-1-5
# 397732  312.50  9990385651939       5-1-5
# 397733  198.90  9990385651946       5-1-5
#
# [397734 rows x 3 columns]

# %%
## Carga de precio creado TOTAL DATOS FALTANTE

data_2.count().sort_values()
# Out:
# precio         395610
# producto_id    397734
# sucursal_id    397734
# dtype: int64

# %%
## Carga de precio creado (TIPO DE DATOS)

data_2.dtypes
# Out:
# precio         object
# producto_id    object
# sucursal_id    object
# dtype: object

# %%
#Saber datos null
data_2.isnull().sum()
# Out:
# precio         0
# producto_id    0
# sucursal_id    0
# dtype: int64

# %%
data_2.producto_id
# Out:
# 0         0000000002288
# 1         0000000002288
# 2         0000000205870
# 3         0000000205870
# 4         0000000205870
#               ...
# 397729    9569753142128
# 397730    9795403001143
# 397731    9990385651922
# 397732    9990385651939
# 397733    9990385651946
# Name: producto_id, Length: 397734, dtype: object

# %%
## Carga de precio creado (COMPLETAR DATOS FALTANTE con 0)

data_2.fillna({'precio': '0'}, inplace=True)

# %%
## Carga de precio creado (MODIFICACION DE DATO OBJECT A FLOAT64)

data_2['precio']=data_2['precio'].astype('float64')

# %%
## Carga de precio creado (CONVERSION A LISTA)

precios_semana_20200503 = data_2.values.tolist()

# %%
## Carga de precio creado (Ver Datos)

precios_semana_20200503
# Out:
# [[29.9, '0000000002288', '2-1-187'],
#  [39.9, '0000000002288', '2-3-247'],
#  [499.99, '0000000205870', '9-1-685'],
#  [539.99, '0000000205870', '9-2-22'],
#  [519.99, '0000000205870', '9-2-59'],
#  [539.99, '0000000205870', '9-3-138'],
#  [589.99, '0000000205894', '9-1-685'],
#  [189.99, '0000000205955', '9-1-685'],
#  [104.99, '0000000205979', '9-1-685'],
#  [229.0, '0000000206020', '9-1-685'],
#  [279.99, '0000000206044', '9-1-685'],
#  [229.99, '0000000206051', '9-1-685'],
#  [459.99, '0000000206105', '9-1-685'],
#  [389.99, '0000000206136', '9-1-685'],
#  [299.99, '0000000206143', '9-1-685'],
#  [339.99, '0000000206181', '9-1-685'],
#  [339.99, '0000000206198', '9-1-685'],
#  [369.99, '0000000206235', '9-1-685'],
#  [399.99, '0000000206280', '9-1-685'],
#  [414.99, '0000000206297', '9-1-685'],
#  [399.99, '0000000206303', '9-1-685'],
#  [399.99, '0000000206310', '9-1-685'],
#  [559.99, '0000000206334', '9-1-685'],
#  [419.99, '0000000206358', '9-1-685'],
# ...

# %% [markdown]
# ## DATO3

# %%
## Carga CSV

data_3 = pd.read_csv("precios_semana_20200518.csv",encoding='utf8', sep= "|")
data_3.head()
# Out:
#    precio    producto_id sucursal_id
# 0   29.90  0000000002288     2-1-009
# 1   32.90  0000000002288     2-1-037
# 2   36.90  0000000002288     2-1-090
# 3   39.90  0000000002288     2-3-247
# 4  499.99  0000000205870     9-1-430

# %%
data_3.count().sort_values()
# Out:
# precio         413333
# producto_id    415287
# sucursal_id    415287
# dtype: int64

# %%
#Saber datos null
data_3.isnull().sum()
# Out:
# precio         0
# producto_id    0
# sucursal_id    0
# dtype: int64

# %%
data_3.producto_id
# Out:
# 0         0000000002288
# 1         0000000002288
# 2         0000000002288
# 3         0000000002288
# 4         0000000205870
#               ...
# 415288    9569753142128
# 415289    9795403001143
# 415290    9990385651922
# 415291    9990385651939
# 415292    9990385651946
# Name: producto_id, Length: 415293, dtype: object

# %%
data_3.dtypes
# Out:
# precio         object
# producto_id    object
# sucursal_id    object
# dtype: object

# %%
## Carga de precio creado (COMPLETAR DATOS FALTANTE con 0)

data_3.fillna({'precio': '0'}, inplace=True)
data_3.fillna({'producto_id': '0'}, inplace=True)
data_3.fillna({'sucursal_id': '0'}, inplace=True)

# %%
## Carga de precio creado (MODIFICACION DE DATO OBJECT A FLOAT64)

data_2['precio']=data_2['precio'].astype('float64')

# %%
## Carga de precio creado (CONVERSION A LISTA)

precios_semana_20200518 = data_3.values.tolist()

# %%
## Carga de precio creado (Ver Datos)

precios_semana_20200518
# Out:
# [[29.9, '0000000002288', '2-1-009'],
#  [32.9, '0000000002288', '2-1-037'],
#  [36.9, '0000000002288', '2-1-090'],
#  [39.9, '0000000002288', '2-3-247'],
#  [499.99, '0000000205870', '9-1-430'],
#  [539.99, '0000000205870', '9-2-4'],
#  [539.99, '0000000205870', '9-3-5205'],
#  [589.99, '0000000205894', '9-1-430'],
#  [189.99, '0000000205955', '9-1-430'],
#  [104.99, '0000000205979', '9-1-430'],
#  [259.99, '0000000206020', '9-1-430'],
#  [279.99, '0000000206044', '9-1-430'],
#  [229.99, '0000000206051', '9-1-430'],
#  [459.99, '0000000206105', '9-1-430'],
#  [389.99, '0000000206136', '9-1-430'],
#  [299.99, '0000000206143', '9-1-430'],
#  [339.99, '0000000206181', '9-1-430'],
#  [339.99, '0000000206198', '9-1-430'],
#  [323.99, '0000000206235', '9-1-430'],
#  [369.99, '0000000206235', '9-1-688'],
#  [329.99, '0000000206280', '9-1-430'],
#  [399.99, '0000000206280', '9-1-688'],
#  [339.99, '0000000206297', '9-1-430'],
#  [414.99, '0000000206297', '9-1-688'],
# ...

# %% [markdown]
# ## DATO4

# %%
## Carga de precio creado

data_4 = pd.read_csv("precios_semanas_20200419_20200426.csv")
data_4.head()
# Out:
#    Unnamed: 0   precio sucursal_id  producto_id
# 0           0    399.0     2-1-092       2288.0
# 1           1    299.0     2-1-206       2288.0
# 2           2    399.0     2-2-241       2288.0
# 3           3  49999.0     9-1-430     205870.0
# 4           4  53999.0       9-2-4     205870.0

# %%
data_4
# Out:
#         Unnamed: 0   precio sucursal_id   producto_id
# 0                0    399.0     2-1-092  2.288000e+03
# 1                1    299.0     2-1-206  2.288000e+03
# 2                2    399.0     2-2-241  2.288000e+03
# 3                3  49999.0     9-1-430  2.058700e+05
# 4                4  53999.0       9-2-4  2.058700e+05
# ...            ...      ...         ...           ...
# 478904      478904  13999.0      25-1-1  9.569753e+12
# 478905      478905   3499.0      25-1-1  9.795403e+12
# 478906      478906   3125.0       5-1-3  9.990386e+12
# 478907      478907   3125.0       5-1-3  9.990386e+12
# 478908      478908   1989.0       5-1-3  9.990386e+12
#
# [478909 rows x 4 columns]

# %%
## Total De columnas Y filas !
data_4.count().sort_values()
# Out:
# producto_id    465390
# precio         477173
# Unnamed: 0     478909
# sucursal_id    478909
# dtype: int64

# %%
data_4.value_counts("sucursal_id")
# Out:
# sucursal_id
# 49-1-2        15083
# 50-1-2        15083
# 25-1-1        12518
# 10-1-48        9976
# 12-1-165       9447
#               ...
# 19-1-01702       11
# 19-1-00421       11
# 23-1-6216         8
# 12-1-35           7
# 15-1-491          4
# Length: 222, dtype: int64

# %%
#Saber datos null
data_4.isnull().sum()
# Out:
# precio         0
# sucursal_id    0
# producto_id    0
# dtype: int64

# %%
#ELIMINACION DE LA COLUMNA 

data_4.drop(columns= ['Unnamed: 0'], inplace = True)

# %%
#VISTA DE LA TABLA

data_4.head()
# Out:
#     precio sucursal_id  producto_id
# 0    399.0     2-1-092       2288.0
# 1    299.0     2-1-206       2288.0
# 2    399.0     2-2-241       2288.0
# 3  49999.0     9-1-430     205870.0
# 4  53999.0       9-2-4     205870.0

# %%
#CONVERSION A STR Y ELIMINACION .0

data_4['producto_id'] = data_4['producto_id'].astype("string").str.rstrip(".0")

# %%
## TRANFORMAR DATOS SIN 0 a +13 Zero

data_4["producto_id"]= data_4["producto_id"].astype(str)

# width of output string
width = 13
  
# calling method and overwriting series
data_4["producto_id"]= data_4["producto_id"].str.zfill(width)
  
# display
data_4
# Out:
#          precio sucursal_id    producto_id
# 0         399.0     2-1-092  0000000002288
# 1         299.0     2-1-206  0000000002288
# 2         399.0     2-2-241  0000000002288
# 3       49999.0     9-1-430  0000000020587
# 4       53999.0       9-2-4  0000000020587
# ...         ...         ...            ...
# 478904  13999.0      25-1-1  9569753142128
# 478905   3499.0      25-1-1  9795403001143
# 478906   3125.0       5-1-3  9990385651922
# 478907   3125.0       5-1-3  9990385651939
# 478908   1989.0       5-1-3  9990385651946
#
# [478909 rows x 3 columns]

# %%
## ELIMINACION DE LOS DATOS CAMPO PRODUCTO y CONVERSION SRT 

data_4['producto_id'] = data_4['producto_id'].str.split('3-1-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('3-2-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('3-3-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('4-1-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('4-2-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('4-4-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('4-5-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('5-1-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('5-2-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('5-4-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('5-5-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('6-1-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('6-2-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('6-4-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('6-5-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('7-1-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('7-2-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('7-4-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('7-5-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('8-1-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('8-2-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('8-4-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('8-5-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('9-1-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('9-2-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('9-3-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('9-4-').str[-1]


data_4['producto_id'] = data_4['producto_id'].str.split('10-1-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('10-2-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('10-3-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('11-1-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('11-2-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('11-4-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('11-5-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('12-1-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('12-2-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('12-3-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('13-1-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('13-2-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('13-3-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('14-1-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('14-2-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('14-3-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('15-1-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('15-2-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('15-4-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('15-5-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('16-1-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('16-2-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('16-3-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('17-1-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('17-2-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('17-3-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('20-1-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('20-2-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('20-3-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('21-1-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('21-2-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('21-3-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('22-1-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('25-1-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('25-2-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('25-3-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('36-3-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('36-4-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('36-5-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('36-6-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('45-1-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('45-2-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('45-3-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('46-1-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('46-2-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('46-3-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('47-1-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('47-2-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('47-3-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('48-1-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('48-2-').str[-1]
data_4['producto_id'] = data_4['producto_id'].str.split('48-3-').str[-1]

# %%
## TIPO DE DATO

data_4.dtypes
# Out:
# precio         float64
# sucursal_id     object
# producto_id     object
# dtype: object

# %%
## Carga de precio creado (COMPLETAR DATOS FALTANTE con 0)

data_4.fillna({'precio': '0'}, inplace=True)

# %%
## Carga de precio creado (MODIFICACION DE DATO OBJECT A FLOAT64)

data_4['precio']=data_4['precio'].astype('float64')

# %%
## MOVIMIENTO DE COLUMNA PRODUCTOS_ID

first_column = data_4.pop('producto_id') 
data_4.insert(1, 'producto_id', first_column)

# %%
## Carga de precio creado (CONVERSION A LISTA)

precios_semanas_20200419_20200426 = data_4.values.tolist()

# %%
## VISTA DE LA LISTA !

precios_semanas_20200419_20200426
# Out:
# [[399.0, '2-1-092', '0000000002288'],
#  [299.0, '2-1-206', '0000000002288'],
#  [399.0, '2-2-241', '0000000002288'],
#  [49999.0, '9-1-430', '0000000020587'],
#  [53999.0, '9-2-4', '0000000020587'],
#  [53999.0, '9-3-5218', '0000000020587'],
#  [58999.0, '9-1-430', '0000000205894'],
#  [18999.0, '9-1-430', '0000000205955'],
#  [10499.0, '9-1-430', '0000000205979'],
#  [2290.0, '9-1-430', '0000000020602'],
#  [27999.0, '9-1-430', '0000000206044'],
#  [2190.0, '9-1-691', '0000000206044'],
#  [22999.0, '9-1-430', '0000000206051'],
#  [45999.0, '9-1-430', '0000000206105'],
#  [38999.0, '9-1-430', '0000000206136'],
#  [29999.0, '9-1-430', '0000000206143'],
#  [2890.0, '9-1-691', '0000000206143'],
#  [33999.0, '9-1-430', '0000000206181'],
#  [33999.0, '9-1-430', '0000000206198'],
#  [36999.0, '9-1-430', '0000000206235'],
#  [3290.0, '9-1-691', '0000000206235'],
#  [39999.0, '9-1-430', '0000000020628'],
#  [3090.0, '9-1-691', '0000000020628'],
#  [41499.0, '9-1-430', '0000000206297'],
# ...

# %% [markdown]
# ## DATO5

# %%
## Carga de PRODUCTO creado

data_5 = pd.read_csv("producto.csv")
data_5.head()
# Out:
#               id       marca                             nombre presentacion  \
# 0  0000000001663  LA ANÓNIMA    Radicheta Atada La Anonima 1 Un       1.0 un
# 1  0000000002288  LA ANÓNIMA      Perejil Atado La Anonima 1 Un       1.0 un
# 2  0000000205870   SIN MARCA                   Ojo de Bife 1 Kg       1.0 kg
# 3  0000000205894   SIN MARCA  Milanesa de Peceto Novillito 1 Kg       1.0 kg
# 4  0000000205955   SIN MARCA         Chiquizuela Novillito 1 Kg       1.0 kg
#
#   categoria1 categoria2 categoria3
# 0        NaN        NaN        NaN
# 1        NaN        NaN        NaN
# 2        NaN        NaN        NaN
# 3        NaN        NaN        NaN
# 4        NaN        NaN        NaN

# %%
data_5
# Out:
#                   id        marca  \
# 0      0000000001663   LA ANÓNIMA
# 1      0000000002288   LA ANÓNIMA
# 2      0000000205870    SIN MARCA
# 3      0000000205894    SIN MARCA
# 4      0000000205955    SIN MARCA
# ...              ...          ...
# 72033  9569753142128  DELI-SITAS
# 72034  9795403001143         MAYO
# 72035  9990385651922         DANA
# 72036  9990385651939         DANA
# 72037  9990385651946         DANA
#
#                                                   nombre presentacion  \
# 0                        Radicheta Atada La Anonima 1 Un       1.0 un
# 1                          Perejil Atado La Anonima 1 Un       1.0 un
# 2                                       Ojo de Bife 1 Kg       1.0 kg
# 3                      Milanesa de Peceto Novillito 1 Kg       1.0 kg
# 4                             Chiquizuela Novillito 1 Kg       1.0 kg
# ...                                                  ...          ...
# ...

# %%
## Total De columnas Y filas !
data_5.count().sort_values()
# Out:
# categoria1          4
# categoria2          4
# categoria3          4
# marca           72036
# nombre          72036
# presentacion    72036
# id              72038
# dtype: int64

# %%
## TIPO DE DATO POR COLUMNA

data_5.dtypes
# Out:
# id              object
# marca           object
# nombre          object
# presentacion    object
# categoria1      object
# categoria2      object
# categoria3      object
# dtype: object

# %%
## ELIMINACION DE COLUMNA CATEGORIA

data_5.drop(columns= ['categoria1'], inplace = True)
data_5.drop(columns= ['categoria2'], inplace = True)
data_5.drop(columns= ['categoria3'], inplace = True)
data_5
# Out:
#                   id        marca  \
# 0      0000000001663   LA ANÓNIMA
# 1      0000000002288   LA ANÓNIMA
# 2      0000000205870    SIN MARCA
# 3      0000000205894    SIN MARCA
# 4      0000000205955    SIN MARCA
# ...              ...          ...
# 72033  9569753142128  DELI-SITAS
# 72034  9795403001143         MAYO
# 72035  9990385651922         DANA
# 72036  9990385651939         DANA
# 72037  9990385651946         DANA
#
#                                                   nombre presentacion
# 0                        Radicheta Atada La Anonima 1 Un       1.0 un
# 1                          Perejil Atado La Anonima 1 Un       1.0 un
# 2                                       Ojo de Bife 1 Kg       1.0 kg
# 3                      Milanesa de Peceto Novillito 1 Kg       1.0 kg
# 4                             Chiquizuela Novillito 1 Kg       1.0 kg
# ...                                                  ...          ...
# ...

# %%
#Saber datos null
data_5.isnull().sum()
# Out:
# id              0
# marca           2
# nombre          2
# presentacion    2
# dtype: int64

# %%
## COMPLETAR DATOS FALTANTE

data_5.fillna({'marca': 'Sin Datos'}, inplace=True)
data_5.fillna({'nombre': 'Sin Datos'}, inplace=True)
data_5.fillna({'presentacion': 'Sin Datos'}, inplace=True)

# %%
## CONVERSION A LISTA

producto = data_5.values.tolist()

# %%
producto
# Out:
# [['0000000001663', 'LA ANÓNIMA', 'Radicheta Atada La Anonima 1 Un', '1.0 un'],
#  ['0000000002288', 'LA ANÓNIMA', 'Perejil Atado La Anonima 1 Un', '1.0 un'],
#  ['0000000205870', 'SIN MARCA', 'Ojo de Bife 1 Kg', '1.0 kg'],
#  ['0000000205894', 'SIN MARCA', 'Milanesa de Peceto Novillito 1 Kg', '1.0 kg'],
#  ['0000000205955', 'SIN MARCA', 'Chiquizuela Novillito 1 Kg', '1.0 kg'],
#  ['0000000205979', 'SIN MARCA', 'Espinazo de Novillito 1 Kg', '1.0 kg'],
#  ['0000000206020', 'SIN MARCA', 'Carnanza Comun de Novillo 1 Kg', '1.0 kg'],
#  ['0000000206044',
#   'SIN MARCA',
#   'Falda Deshuesada Novillito Bandeja 1 Kg',
#   '1.0 kg'],
#  ['0000000206051', 'SIN MARCA', 'Carne Picada Comun 1 Kg', '1.0 kg'],
#  ['0000000206105', 'SIN MARCA', 'Entraña de Novillito 1 Kg', '1.0 kg'],
#  ['0000000206136', 'SIN MARCA', 'Bife Ancho de Novillito 1 Kg', '1.0 kg'],
#  ['0000000206143',
#   'SIN MARCA',
#   'Rost Beef en Trozo de Novillito 1 Kg',
#   '1.0 kg'],
# ...

# %% [markdown]
# ## DATA6

# %%
## Carga de SUCURSAL creado

data_6 = pd.read_csv("sucursal.csv")
data_6.head()
# Out:
#          id  comercioId  banderaId      banderaDescripcion  \
# 0     1-1-7           1          1              Super MAMI
# 1    10-1-1          10          1  Hipermercado Carrefour
# 2   10-1-10          10          1  Hipermercado Carrefour
# 3   10-1-11          10          1  Hipermercado Carrefour
# 4  10-1-112          10          1  Hipermercado Carrefour
#
#   comercioRazonSocial provincia            localidad  \
# 0     Dinosaurio S.A.      AR-X          SALSIPUEDES
# 1            INC S.A.      AR-B           San Isidro
# 2            INC S.A.      AR-B           Hurlingham
# 3            INC S.A.      AR-B  Malvinas Argentinas
# 4            INC S.A.      AR-A                Salta
#
#                    direccion        lat        lng       sucursalNombre  \
# 0              E53 1011 None -31.126667 -64.295250         Super Mami 4
# 1  Bernardo De Irigoyen 2647 -34.491345 -58.589025           San Isidro
# ...

# %%
data_6
# Out:
#             id  comercioId  banderaId      banderaDescripcion  \
# 0        1-1-7           1          1              Super MAMI
# 1       10-1-1          10          1  Hipermercado Carrefour
# 2      10-1-10          10          1  Hipermercado Carrefour
# 3      10-1-11          10          1  Hipermercado Carrefour
# 4     10-1-112          10          1  Hipermercado Carrefour
# ...        ...         ...        ...                     ...
# 2328  9-3-5277           9          3                   Jumbo
# 2329  9-3-5626           9          3                   Jumbo
# 2330  9-3-5961           9          3                   Jumbo
# 2331   9-3-628           9          3                   Jumbo
# 2332   9-3-662           9          3                   Jumbo
#
#               comercioRazonSocial provincia                     localidad  \
# 0                 Dinosaurio S.A.      AR-X                   SALSIPUEDES
# ...

# %%
## Total De columnas Y filas !
data_6.count().sort_values()
# Out:
# id                     2333
# comercioId             2333
# banderaId              2333
# banderaDescripcion     2333
# comercioRazonSocial    2333
# provincia              2333
# localidad              2333
# direccion              2333
# lat                    2333
# lng                    2333
# sucursalNombre         2333
# sucursalTipo           2333
# dtype: int64

# %%
## TYPO DE DATOS DE CADA COLUMNA

data_6.dtypes
# Out:
# id                      object
# comercioId               int64
# banderaId                int64
# banderaDescripcion      object
# comercioRazonSocial     object
# provincia               object
# localidad               object
# direccion               object
# lat                    float64
# lng                    float64
# sucursalNombre          object
# sucursalTipo            object
# dtype: object

# %%
#Saber datos null
data_6.isnull().sum()
# Out:
# id                     0
# comercioId             0
# banderaId              0
# banderaDescripcion     0
# comercioRazonSocial    0
# provincia              0
# localidad              0
# direccion              0
# lat                    0
# lng                    0
# sucursalNombre         0
# sucursalTipo           0
# dtype: int64

# %%
## CONVERSION A LISTA

sucursal = data_6.values.tolist()

# %%
## VISTA

sucursal
# Out:
# [['1-1-7',
#   1,
#   1,
#   'Super MAMI',
#   'Dinosaurio S.A.',
#   'AR-X',
#   'SALSIPUEDES',
#   'E53 1011 None',
#   -31.126667,
#   -64.29525,
#   'Super Mami 4',
#   'Hipermercado'],
#  ['10-1-1',
#   10,
#   1,
#   'Hipermercado Carrefour',
#   'INC S.A.',
#   'AR-B',
#   'San Isidro',
#   'Bernardo De Irigoyen 2647',
#   -34.491345,
#   -58.589025,
#   'San Isidro',
#   'Hipermercado'],
#  ['10-1-10',
#   10,
#   1,
#   'Hipermercado Carrefour',
#   'INC S.A.',
#   'AR-B',
#   'Hurlingham',
#   'Av. Vergara 1910',
#   -34.62061,
#   -58.633769,
#   'Villa Tesei',
#   'Hipermercado'],
#  ['10-1-11',
#   10,
#   1,
#   'Hipermercado Carrefour',
#   'INC S.A.',
#   'AR-B',
#   'Malvinas Argentinas',
#   'Av. Arturo Illia 3770',
#   -34.528883,
#   -58.701631000000006,
#   'Malvinas Argentinas',
#   'Hipermercado'],
#  ['10-1-112',
#   10,
#   1,
#   'Hipermercado Carrefour',
#   'INC S.A.',
#   'AR-A',
#   'Salta',
#   '20 De Febrero 37',
#   -24.789072,
#   -65.413699,
# ...

# %% [markdown]
# ## CARGAS DE DATO MEDIANTE PYODBC !

# %%
import pyodbc

driver='{MySQL ODBC 8.0 ANSI Driver}'
server='127.0.0.1'
database='dbapi'
username='root'
password='1020'


cnxn = pyodbc.connect('DRIVER={MySQL ODBC 8.0 ANSI Driver};SERVER='+server+';DATABASE='+database+';UID='+username+';PWD='+ password)
print("Conexión Exitosa")

cursor = cnxn.cursor()
# Out:
# Conexión Exitosa

# %%
cnxn.execute("CREATE TABLE precios_semana_20200425_ok1(Precio DECIMAL(18,2), Producto_id VARCHAR(225) ,Sucursal_id VARCHAR(225))")

# %%
## CARGA DE DATOS DESDE PYTHON A MYSQL Worbench precios_semana_20200413

cursor.executemany("INSERT INTO precios_semana_20200413 VALUES(?,?,?)", precios_semana_20200413)

# %%
## CARGA DE DATOS DESDE PYTHON A MYSQL Worbench precios_semana_20200503

cursor.executemany("INSERT INTO precios_semana_20200503 VALUES(?,?,?)", precios_semana_20200503)

# %%
## CARGA DE DATOS DESDE PYTHON A MYSQL Worbench precios_semana_20200518

cursor.executemany("INSERT INTO precios_semana_20200518 VALUES(?,?,?)", precios_semana_20200518)

# %%
## CARGA DE DATOS DESDE PYTHON A MYSQL Worbench precios_semanas_20200419_20200426

cursor.executemany("INSERT INTO precios_semanas_20200419_20200426_ok2 VALUES(?,?,?)", precios_semanas_20200419_20200426)

# %%
## CARGA DE TABLAS DESDE PYTHON A MYSQL ((PRUEBA NO SE UTILIZO ))

cnxn.execute("CREATE TABLE Sucursal(Sucursal_id varchar(255) null, comercioId int(15) null, banderaId int(15) null, banderaDescripcion varchar(255) null,	comercioRazonSocial varchar(255) null, provincia varchar(255) null, localidad varchar(255) null,	direccion varchar(255) null,	lat DECIMAL(15,6),	lng DECIMAL(15,6) ,	sucursalNombre varchar(255) null,sucursalTipo varchar(255) null)")

# %%
## CARGA DE DATOS DESDE PYTHON A MYSQL Worbench Sucursal

cursor.executemany("INSERT INTO Sucursal VALUES(?,?,?,?,?,?,?,?,?,?,?,?)", sucursal)

# %%
## CARGA DE TABLAS DESDE PYTHON A MYSQL ((PRUEBA NO SE UTILIZO))

cnxn.execute("CREATE TABLE Producto(Producto_id VARCHAR(225), marca	VARCHAR(225),nombre VARCHAR(225),presentacion VARCHAR(225)), PRIMARY KEY (Producto_id))")
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In [152], line 1
# ----> 1 cnxn.execute("CREATE TABLE Producto(Producto_id VARCHAR(225), marca	VARCHAR(225),nombre VARCHAR(225),presentacion VARCHAR(225)), PRIMARY KEY (Producto_id))")
#
# ProgrammingError: ('42000', "[42000] [MySQL][ODBC 8.0(a) Driver][mysqld-8.0.30]You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near ', PRIMARY KEY (Producto_id))' at line 1 (1064) (SQLExecDirectW)")

# %%
## CARGA DE DATOS DESDE PYTHON A MYSQL Worbench Producto

cursor.executemany("INSERT INTO Producto VALUES(?,?,?,?)", producto)

# %%
## VISUALIZACION O INJESTA DE LOS DATO A MYSQL

cnxn.commit()

# %%
cnxn.close()

# %% [markdown]
# ## Modificacion De Encoding utf-16 a utf-8

# %%
import codecs
import shutil

# %%
##Modificacion De Encoding utf-16 a utf-8

with codecs.open("precios_semana_20200413.csv", encoding="utf-16") as input_file:
    with codecs.open("8_precios_semana_20200413.csv", "w", encoding="utf-8") as output_file:
        shutil.copyfileobj(input_file, output_file)
